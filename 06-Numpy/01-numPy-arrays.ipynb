# %%
import numpy as np

# %% [markdown]
# ### 1) Basic Array Creation

# %%
arr = np.array([1,2,3,4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
a = [1,2,3.5,False]
a
# Out:
# [1, 2, 3, 4]

# %%
np.array(a)
